# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Call the Dataset

# %%
dataset = pd.read_csv(r'hotel_bookings_data.csv')
dataset.sample(6)
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 75349    City Hotel            1        311               2017
# 1767   Resort Hotel            1        120               2017
# 2508   Resort Hotel            0         47               2017
# 19417  Resort Hotel            0          1               2017
# 533    Resort Hotel            0         94               2017
# 85675    City Hotel            0        115               2018
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 75349            October                        35                         24
# 1767            November                        38                         13
# 2508            December                        43                         19
# 19417           February                        51                         18
# 533            September                        29                         18
# ...

# %%
dataset.shape
# Out:
# (119390, 29)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_weekdays_nights        119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# # Statistic Data

# %%
dataset.describe().T
# Out:
#                                    count         mean         std      min  \
# is_canceled                     119390.0     0.370416    0.482918     0.00
# lead_time                       119390.0   104.011416  106.863097     0.00
# arrival_date_year               119390.0  2018.156554    0.707476  2017.00
# arrival_date_week_number        119390.0    27.165173   13.605138     1.00
# arrival_date_day_of_month       119390.0    15.798241    8.780829     1.00
# stays_in_weekend_nights         119390.0     0.927599    0.998613     0.00
# stays_in_weekdays_nights        119390.0     2.500302    1.908286     0.00
# adults                          119390.0     1.856403    0.579261     0.00
# children                        119386.0     0.103890    0.398561     0.00
# babies                          119390.0     0.007949    0.097436     0.00
# is_repeated_guest               119390.0     0.031912    0.175767     0.00
# ...

# %%
df = dataset.copy()
df.sample(6)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 99196   City Hotel            0        338               2018
# 71021   City Hotel            1        138               2019
# 42352   City Hotel            1         65               2017
# 106220  City Hotel            0          6               2019
# 103428  City Hotel            0        127               2018
# 98799   City Hotel            0         18               2018
#
#        arrival_date_month  arrival_date_week_number  \
# 99196            December                        41
# 71021              August                        26
# 42352            November                        36
# 106220              April                         8
# 103428           February                        52
# 98799            December                        41
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 99196                           7                        1
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_weekdays_nights', 'adults', 'children', 'babies', 'meal',
#        'city', 'market_segment', 'distribution_channel', 'is_repeated_guest',
#        'previous_cancellations', 'previous_bookings_not_canceled',
#        'booking_changes', 'deposit_type', 'agent', 'company',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status'],
#       dtype='object')

# %% [markdown]
# # EDA

# %% [markdown]
# ## Handle Missing Value

# %%
df.isnull().any()
# Out:
# hotel                             False
# is_canceled                       False
# lead_time                         False
# arrival_date_year                 False
# arrival_date_month                False
# arrival_date_week_number          False
# arrival_date_day_of_month         False
# stays_in_weekend_nights           False
# stays_in_weekdays_nights          False
# adults                            False
# children                           True
# babies                            False
# meal                              False
# city                               True
# market_segment                    False
# distribution_channel              False
# is_repeated_guest                 False
# previous_cancellations            False
# previous_bookings_not_canceled    False
# booking_changes                   False
# deposit_type                      False
# agent                              True
# company                            True
# ...

# %% [markdown]
# ### Children - Mode (Missing Value)

# %%
df.children.fillna(df.children.mode()[0], inplace=True)

# %% [markdown]
# ### Agent - Median (Missing Value)

# %%
df.agent.fillna(df.agent.median(), inplace=True)

# %% [markdown]
# ### Company - Median (Missing Value)

# %%
df.company.fillna(df.company.median(), inplace=True)

# %% [markdown]
# ### City - Mode (Missing Value)

# %%
df.city.fillna(df.city.mode()[0], inplace=True)

# %% [markdown]
# ## Univariate Analysis

# %%
numerical = df [['lead_time','arrival_date_week_number','arrival_date_day_of_month','stays_in_weekend_nights',
                 'stays_in_weekdays_nights','adults','children','babies', 'previous_cancellations', 'previous_bookings_not_canceled',
                 'booking_changes','agent','company','days_in_waiting_list','adr']]
numerical.sample(5)
# Out:
#         lead_time  arrival_date_week_number  arrival_date_day_of_month  \
# 110234         44                        16                         20
# 12908          84                        29                         22
# 53609         163                        26                         25
# 55627         405                        34                         18
# 2775          155                        44                         31
#
#         stays_in_weekend_nights  stays_in_weekdays_nights  adults  children  \
# 110234                        1                         3       2       0.0
# 12908                         2                         6       2       0.0
# 53609                         1                         1       2       0.0
# 55627                         0                         2       2       0.0
# 2775                          0                         1       2       0.0
#
#         babies  previous_cancellations  previous_bookings_not_canceled  \
# ...

# %%
numerical1 = df[['lead_time','arrival_date_week_number','arrival_date_day_of_month','stays_in_weekend_nights',
                 'stays_in_weekdays_nights']]
numerical1 = numerical1.columns
numerical1
# Out:
# Index(['lead_time', 'arrival_date_week_number', 'arrival_date_day_of_month',
#        'stays_in_weekend_nights', 'stays_in_weekdays_nights'],
#       dtype='object')

# %%
numerical2 = df[['adults','children','babies','previous_cancellations', 'previous_bookings_not_canceled']]
numerical2 = numerical2.columns
numerical2
# Out:
# Index(['adults', 'children', 'babies', 'previous_cancellations',
#        'previous_bookings_not_canceled'],
#       dtype='object')

# %%
numerical3 = df[['booking_changes','agent','company','days_in_waiting_list','adr']]
numerical3 = numerical3.columns
numerical3
# Out:
# Index(['booking_changes', 'agent', 'company', 'days_in_waiting_list', 'adr'], dtype='object')

# %%
from matplotlib import rcParams

rcParams['figure.figsize'] = 12, 10
rcParams['lines.linewidth'] = 3
rcParams['xtick.labelsize'] = 'x-large'
rcParams['ytick.labelsize'] = 'x-large'

# %%
for i in range(0, len(numerical1)):
    plt.subplot(1, len(numerical1), i+1)
    sns.boxplot(y= df[numerical1[i]], color='blue', orient='v')
    plt.tight_layout()

# %%
for i in range (0,len(numerical1)):
    plt.subplot(2,3, i+1)
    sns.histplot(x=df[numerical1[i]], color='blue')
    plt.xlabel(numerical1[i])
    plt.tight_layout()

# %%
for i in range (0,len(numerical1)):
    plt.subplot(2,3, i+1)
    sns.kdeplot(x=df[numerical1[i]], color='blue')
    plt.xlabel(numerical1[i])
    plt.tight_layout()

# %%
for i in range(0, len(numerical2)):
    plt.subplot(1, len(numerical2), i+1)
    sns.boxplot(y= df[numerical2[i]], color='green', orient='v')
    plt.tight_layout()

# %%
for i in range (0,len(numerical2)):
    plt.subplot(2,3, i+1)
    sns.histplot(x=df[numerical2[i]], color='green')
    plt.xlabel(numerical2[i])
    plt.tight_layout()

# %%
for i in range (0,len(numerical2)):
    plt.subplot(2,3, i+1)
    sns.kdeplot(x=df[numerical2[i]], color='green')
    plt.xlabel(numerical2[i])
    plt.tight_layout()

# %%
for i in range(0, len(numerical3)):
    plt.subplot(1, len(numerical3), i+1)
    sns.boxplot(y= df[numerical3[i]], color='red', orient='v')
    plt.tight_layout()

# %%
for i in range (0,len(numerical3)):
    plt.subplot(2,3, i+1)
    sns.histplot(x=df[numerical3[i]], color='red')
    plt.xlabel(numerical3[i])
    plt.tight_layout()

# %%
for i in range (0,len(numerical3)):
    plt.subplot(2,3, i+1)
    sns.kdeplot(x=df[numerical3[i]], color='red')
    plt.xlabel(numerical3[i])
    plt.tight_layout()

# %% [markdown]
# ## Individual Countplot

# %%
categorial = df[['hotel', 'is_canceled','arrival_date_year','meal','city',
                 'market_segment', 'distribution_channel', 'is_repeated_guest',
                 'deposit_type','customer_type','required_car_parking_spaces', 'total_of_special_requests',
                 'reservation_status']]

# %%
categorial1 = df[['hotel', 'is_canceled','arrival_date_year','meal']]
categorial1 = categorial1.columns
categorial1
# Out:
# Index(['hotel', 'is_canceled', 'arrival_date_year', 'meal'], dtype='object')

# %%
#pip install --upgrade seaborn

# %%
for i in range (0, len(categorial1)):
    plt.subplot(1,len(categorial1),i+1)
    sns.countplot(x=df[categorial1[i]], orient='h')
    plt.xticks(rotation=90)
    plt.tight_layout()

# %%
categorial2 = df[['market_segment', 'distribution_channel', 'is_repeated_guest',
                 'deposit_type']]
categorial2 = categorial2.columns
categorial2
# Out:
# Index(['market_segment', 'distribution_channel', 'is_repeated_guest',
#        'deposit_type'],
#       dtype='object')

# %%
for i in range (0, len(categorial2)):
    plt.subplot(1,len(categorial2),i+1)
    sns.countplot(x=df[categorial2[i]], orient='h')
    plt.xticks(rotation=90)
    plt.tight_layout()

# %%
categorial3=df[['customer_type','required_car_parking_spaces', 'total_of_special_requests',
                 'reservation_status']]
categorial3 =categorial3.columns
categorial3
# Out:
# Index(['customer_type', 'required_car_parking_spaces',
#        'total_of_special_requests', 'reservation_status'],
#       dtype='object')

# %%
for i in range (0, len(categorial3)):
    plt.subplot(1,len(categorial3),i+1)
    sns.countplot(x=df[categorial3[i]], orient='h')
    plt.xticks(rotation=90)
    plt.tight_layout()

# %% [markdown]
# ## Multivariate Analysis

# %%
numerical = df [['lead_time','arrival_date_week_number','arrival_date_day_of_month','stays_in_weekend_nights',
                 'stays_in_weekdays_nights','adults','children','babies', 'previous_cancellations', 'previous_bookings_not_canceled',
                 'booking_changes','agent','company','days_in_waiting_list','adr']]
numerical.describe().T
# Out:
#                                    count        mean         std   min  \
# lead_time                       119390.0  104.011416  106.863097  0.00
# arrival_date_week_number        119390.0   27.165173   13.605138  1.00
# arrival_date_day_of_month       119390.0   15.798241    8.780829  1.00
# stays_in_weekend_nights         119390.0    0.927599    0.998613  0.00
# stays_in_weekdays_nights        119390.0    2.500302    1.908286  0.00
# adults                          119390.0    1.856403    0.579261  0.00
# children                        119390.0    0.103886    0.398555  0.00
# babies                          119390.0    0.007949    0.097436  0.00
# previous_cancellations          119390.0    0.087118    0.844336  0.00
# previous_bookings_not_canceled  119390.0    0.137097    1.497437  0.00
# booking_changes                 119390.0    0.221124    0.652306  0.00
# agent                           119390.0   76.744392  105.904658  1.00
# ...

# %%
sns.heatmap(numerical.corr(), annot=True, cmap='Blues', fmt='.2f')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x='lead_time', y='agent', data=df, hue='hotel')
plt.title('Lead Time and Agent')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x='lead_time', y='company', data=df, hue='hotel')
plt.title('Lead Time and Company')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x='lead_time', y='days_in_waiting_list', data=df, hue='hotel')
plt.title('Lead Time and days_in_waiting_list')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x='lead_time', y='adr', data=df, hue='hotel')
plt.title('Lead Time and ADR')
plt.ylim(0,1000)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x='agent', y='company', data=df, hue='hotel')
plt.title('Agent and Company')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x='agent', y='days_in_waiting_list', data=df, hue='hotel')
plt.title('Agent and days_in_waiting_list')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x='agent', y='adr', data=df, hue='hotel')
plt.title('Agent and ADR')
plt.ylim(0,1000)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x='company', y='days_in_waiting_list', data=df, hue='hotel')
plt.title('Company and days_in_waiting_list')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x='company', y='adr', data=df, hue='hotel')
plt.title('Company and ADR')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x='days_in_waiting_list', y='adr', data=df, hue='hotel')
plt.title('days_in_waiting_list and ADR')
plt.ylim(0,1000)
plt.show()

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Feature Extraction

# %% [markdown]
# ### Visitor

# %%
df['visitor'] = df['adults']+df['children']+df['babies']

# %% [markdown]
# ### Total_Booking

# %%
df['Total_Booking'] = df['previous_cancellations']+df['previous_bookings_not_canceled']

# %%
df[ 'previous_bookings_not_canceled'].value_counts()
# Out:
# 0     115770
# 1       1542
# 2        580
# 3        333
# 4        229
#        ...
# 47         1
# 49         1
# 50         1
# 51         1
# 72         1
# Name: previous_bookings_not_canceled, Length: 73, dtype: int64

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_weekdays_nights', 'adults', 'children', 'babies', 'meal',
#        'city', 'market_segment', 'distribution_channel', 'is_repeated_guest',
#        'previous_cancellations', 'previous_bookings_not_canceled',
#        'booking_changes', 'deposit_type', 'agent', 'company',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'visitor', 'Total_Booking'],
#       dtype='object')

# %% [markdown]
# ## Handling Feature

# %% [markdown]
# ### Drop Feature

# %%
df = df.drop(['lead_time','adults', 'children', 'babies',
              'distribution_channel','previous_cancellations', 'previous_bookings_not_canceled'], axis = 1)
df.sample(5)
# Out:
#                hotel  is_canceled  arrival_date_year arrival_date_month  \
# 91537     City Hotel            0               2018             August
# 23322   Resort Hotel            0               2018               June
# 64741     City Hotel            1               2019                May
# 35686   Resort Hotel            0               2019               June
# 109301    City Hotel            0               2019               June
#
#         arrival_date_week_number  arrival_date_day_of_month  \
# 91537                         26                         19
# 23322                         16                         16
# 64741                         11                         15
# 35686                         16                         22
# 109301                        14                          7
#
#         stays_in_weekend_nights  stays_in_weekdays_nights       meal  \
# 91537                         2                         2  Breakfast
# ...

# %% [markdown]
# ### Required Car Parking Spaces - Invalid Values

# %%
df['required_car_parking_spaces'] = np.where(df['required_car_parking_spaces']==0, 'Not Required', 'Required')

# %% [markdown]
# ### Meal - Invalid Values

# %%
df['meal']=np.where(df['meal'].isin(['Breakfast']), "Breakfast",
                               np.where(df['meal'].isin(['Full Board']), 'Full Board',
                                        np.where(df['meal'].isin(['Undefined']), 'No Meal', 'Dinner')))
df.head()
# Out:
#           hotel  is_canceled  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0               2017          September
# 1  Resort Hotel            0               2017          September
# 2  Resort Hotel            0               2017          September
# 3  Resort Hotel            0               2017          September
# 4  Resort Hotel            0               2017          September
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_weekdays_nights       meal  \
# 0                        0                         0  Breakfast
# 1                        0                         0  Breakfast
# ...

# %% [markdown]
# ## Split Data

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('is_canceled', axis=1),df['is_canceled'] ,
                                   random_state=42, 
                                   test_size=0.2, shuffle=False)

# %%
train = X_train.join(y_train)
train.shape
# Out:
# (95512, 24)

# %%
test = X_test.join(y_test)
test.shape
# Out:
# (23878, 24)

# %% [markdown]
# ## Handle Outliers

# %% [markdown]
# ### Stays in Weekend Nights > 11

# %%
train.columns
# Out:
# Index(['hotel', 'arrival_date_year', 'arrival_date_month',
#        'arrival_date_week_number', 'arrival_date_day_of_month',
#        'stays_in_weekend_nights', 'stays_in_weekdays_nights', 'meal', 'city',
#        'market_segment', 'is_repeated_guest', 'booking_changes',
#        'deposit_type', 'agent', 'company', 'days_in_waiting_list',
#        'customer_type', 'adr', 'required_car_parking_spaces',
#        'total_of_special_requests', 'reservation_status', 'visitor',
#        'Total_Booking', 'is_canceled'],
#       dtype='object')

# %%
for i in ['stays_in_weekend_nights']:
  print(f'Jumlah baris sebelum memfilter',i, 'outlier:', len(train))
  a = len(train)
  train=train[train[i]<=11]
  print(f'Jumlah baris setelah memfilter',i, 'outlier:', len(train))
  b = len(train)
  print (f'persen yang dibuang : {100-((b/a)*100)}')
# Out:
# Jumlah baris sebelum memfilter stays_in_weekend_nights outlier: 95512
# Jumlah baris setelah memfilter stays_in_weekend_nights outlier: 95499
# persen yang dibuang : 0.013610855180502313

# %% [markdown]
# ### Stays in Weekdays Nights

# %%
for i in ['stays_in_weekdays_nights']:
  print(f'Jumlah baris sebelum memfilter',i, 'outlier:', len(train))
  a = len(train)
  train=train[train[i]<=35]
  print(f'Jumlah baris setelah memfilter',i, 'outlier:', len(train))
  b = len(train)
  print (f'persen yang dibuang : {100-((b/a)*100)}')
# Out:
# Jumlah baris sebelum memfilter stays_in_weekdays_nights outlier: 95499
# Jumlah baris setelah memfilter stays_in_weekdays_nights outlier: 95499
# persen yang dibuang : 0.0

# %% [markdown]
# ### Days in Waiting List

# %%
for i in ['days_in_waiting_list']:
  print(f'Jumlah baris sebelum memfilter',i, 'outlier:', len(train))
  a = len(train)
  train=train[train[i]<=300]
  print(f'Jumlah baris setelah memfilter',i, 'outlier:', len(train))
  b = len(train)
  print (f'persen yang dibuang : {100-((b/a)*100)}')
# Out:
# Jumlah baris sebelum memfilter days_in_waiting_list outlier: 89879
# Jumlah baris setelah memfilter days_in_waiting_list outlier: 89879
# persen yang dibuang : 0.0

# %% [markdown]
# ### ADR

# %%
for i in ['adr']:
  print(f'Jumlah baris sebelum memfilter',i, 'outlier:', len(train))
  a = len(train)
  train=train[train[i]<=1000]
  print(f'Jumlah baris setelah memfilter',i, 'outlier:', len(train))
  b = len(train)
  print (f'persen yang dibuang : {100-((b/a)*100)}')
# Out:
# Jumlah baris sebelum memfilter adr outlier: 95424
# Jumlah baris setelah memfilter adr outlier: 95423
# persen yang dibuang : 0.0010479543930301816

# %% [markdown]
# ### Visitor

# %%
for i in ['visitor']:
  print(f'Jumlah baris sebelum memfilter',i, 'outlier:', len(train))
  a = len(train)
  train=train[train[i]<=15]
  print(f'Jumlah baris setelah memfilter',i, 'outlier:', len(train))
  b = len(train)
  print (f'persen yang dibuang : {100-((b/a)*100)}')
# Out:
# Jumlah baris sebelum memfilter visitor outlier: 95423
# Jumlah baris setelah memfilter visitor outlier: 95411
# persen yang dibuang : 0.012575584502684478

# %% [markdown]
# ### Total Booking

# %%
for i in ['Total_Booking']:
  print(f'Jumlah baris sebelum memfilter',i, 'outlier:', len(train))
  a = len(train)
  train=train[train[i]<=40]
  print(f'Jumlah baris setelah memfilter',i, 'outlier:', len(train))
  b = len(train)
  print (f'persen yang dibuang : {100-((b/a)*100)}')
# Out:
# Jumlah baris sebelum memfilter Total_Booking outlier: 95411
# Jumlah baris setelah memfilter Total_Booking outlier: 95373
# persen yang dibuang : 0.03982769282367826

# %% [markdown]
# ### Company

# %%
for i in ['company']:
  print(f'Jumlah baris sebelum memfilter',i, 'outlier:', len(train))
  a = len(train)
  train=train[(train[i]<=190)&
             (train[i]>=170)]
  print(f'Jumlah baris setelah memfilter',i, 'outlier:', len(train))
  b = len(train)
  print (f'persen yang dibuang : {100-((b/a)*100)}')
# Out:
# Jumlah baris sebelum memfilter company outlier: 95373
# Jumlah baris setelah memfilter company outlier: 89879
# persen yang dibuang : 5.760540194814041

# %% [markdown]
# ### Agent

# %%
for i in ['agent']:
  Q1 = train[i].quantile(.25)
  Q3 = train[i].quantile(.75)
  IQR = Q3 - Q1
  Batas_Atas = Q3 + 1.5*IQR
  Batas_Bawah = Q1 - 1.5*IQR
  print(f'Jumlah baris sebelum memfilter',i, 'outlier:', len(train))
  a = len(train)
  train=train[(train[i]<=Batas_Atas)&
              (train[i]>=Batas_Bawah)]

  print(f'Jumlah baris setelah memfilter',i, 'outlier:', len(train))
  b = len(train)
  print (f'persen yang dibuang : {100-((b/a)*100)}')
# Out:
# Jumlah baris sebelum memfilter agent outlier: 89879
# Jumlah baris setelah memfilter agent outlier: 89879
# persen yang dibuang : 0.0

# %%
sns.histplot(x='company', data=train)
# Out:
# <AxesSubplot:xlabel='company', ylabel='Count'>

# %%
df.company.describe()
# Out:
# count    119390.000000
# mean        179.584496
# std          31.500968
# min           6.000000
# 25%         179.000000
# 50%         179.000000
# 75%         179.000000
# max         543.000000
# Name: company, dtype: float64
